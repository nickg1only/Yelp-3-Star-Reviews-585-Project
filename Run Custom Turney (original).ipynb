# %%
import CustomTurneyYelp as cty
# Out:
# Initializing Custom Turney
# Initializing training sets
# ...
# 100%|██████████| 100/100 [00:12<00:00,  8.19it/s]
# Streaming lexicons

# %%
reload(cty)
# Out:
# Initializing Custom Turney
# Initializing training sets
# ...
# 100%|██████████| 100/100 [00:11<00:00,  8.52it/s]
# Streaming lexicons
# <module 'CustomTurneyYelp' from 'CustomTurneyYelp.py'>

# %%
cty.train_turney()
# Out:
# Parsing positive training set
# Parsing reviews in pos training set: 100%|██████████| 100/100 [00:01<00:00, 72.10it/s]
# Parsing negative training set
# Parsing reviews in neg training set: 100%|██████████| 100/100 [00:02<00:00, 47.94it/s]
# Calculating polarity scores
# 100%|██████████| 1460/1460 [00:00<00:00, 18250.02it/s]

# %%
#cty.test_turney()

# %%
cty.print_top_five_polarized_nouns()
# Out:
# [('teas', 17.67576584729894), ('youre', 16.99769610622183), ('pot', 16.877402374308993), ('music', 16.74615843841727), ('ambiance', 16.74615843841727), ('truck', 16.260734359221882), ('price', 16.260734359221882), ('everyone', 16.260734359221882), ('study', 16.161199372663862), ('wifi', 16.05428496143105)]
#
# [('milk', -17.22160864699572), ('thru', -17.391531644718572), ('orders', -17.391531644718572), ('mediocre', -17.391531644718572), ('store', -17.681035347407562), ('drive', -17.681035347407562), ('customer', -17.681035347407562), ('im', -17.80656513655015), ('bread', -18.028955840405796), ('card', -18.221599630236245)]

# %%
cty.print_noun_polarity_scores()
# Out:
# {'saver': -0.9338782338709675, 'minuscule': -0.9338782338709675, 'buddy': -0.9338782338709675, 'bimbos': -14.221734875711512, 'worth': 14.353870212603669, 'lack': -2.93377003850506, 'updates': -0.9338782338709675, 'school': -0.9338782338709675, 'basics': 12.353978407969578, 'prize': -0.9338782338709675, 'clientele': 13.938844735432857, 'venue': 13.938844735432857, 'boohoo': -0.9338782338709675, 'frozen': -15.221662746369153, 'convenience': -0.9338782338709675, 'heading': -0.9338782338709675, 'Screw': -0.9338782338709675, 'phones': -0.9338782338709675, 'bacon': -0.9338782338709675, 'lavender': 13.938844735432857, 'chef': 14.353870212603669, 'talks': -14.221734875711512, 'louder': -0.9338782338709675, 'cooking': -0.9338782338709675, 'fingers': -14.221734875711512, 'lights': -0.9338782338709675, 'Put': -0.9338782338709675, 'supplies': -14.221734875711512, 'tips': -15.806601203174791, 'counters': 12.353978407969578, 'textures': -0.9338782338709675, 'pancakes': -0.9338782338709675, 'men':
# ...
